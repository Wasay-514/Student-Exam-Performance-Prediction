# %% [markdown]
# ## Student Exam Performance Prediction

# %% [markdown]
# This is a beginner-friendly professional project for learning:
#
# - Python
# - Pandas
# - Data Cleaning
# - EDA
# - Machine Learning Basics
# - Problem Statement
#
# A school wants to predict whether a student will pass or fail based on:
#
# ### **Target variables**
#
# - Study hours
# - Attendance
# - Sleep hours
# - Previous grades
# - Internet usage
# - Assignment completion
#
# Your task:
# Build a machine learning model that predicts student performance and identifies factors affecting marks.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('student_performance_dataset.csv')

# %%
df
# Out:
#     StudentID  Gender  Age  StudyHoursPerDay  AttendancePercentage  \
# 0    STD-1000    Male   23               2.9                    49
# 1    STD-1001    Male   18               0.8                    67
# 2    STD-1002  Female   17               4.8                    65
# 3    STD-1003    Male   23               4.8                    75
# 4    STD-1004  Female   20               4.7                    79
# ..        ...     ...  ...               ...                   ...
# 995  STD-1995  Female   21               1.8                    76
# 996  STD-1996  Female   23               5.2                    54
# 997  STD-1997    Male   21               4.7                    97
# 998  STD-1998    Male   23               2.5                    87
# 999  STD-1999    Male   23               2.0                    90
#
#      AssignmentsCompleted  SleepHours  PreviousGrade  InternetUsageHours  \
# 0                       6         7.9             44                 8.4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   StudentID             1000 non-null   object
#  1   Gender                1000 non-null   object
#  2   Age                   1000 non-null   int64
#  3   StudyHoursPerDay      1000 non-null   float64
#  4   AttendancePercentage  1000 non-null   int64
#  5   AssignmentsCompleted  1000 non-null   int64
#  6   SleepHours            1000 non-null   float64
#  7   PreviousGrade         1000 non-null   int64
#  8   InternetUsageHours    1000 non-null   float64
#  9   ExtraClasses          1000 non-null   object
#  10  Result                1000 non-null   object
# dtypes: float64(3), int64(4), object(4)
# memory usage: 86.1+ KB

# %%
df.shape
# Out:
# (1000, 11)

# %%
df.dtypes
# Out:
# StudentID                object
# Gender                   object
# Age                       int64
# StudyHoursPerDay        float64
# AttendancePercentage      int64
# AssignmentsCompleted      int64
# SleepHours              float64
# PreviousGrade             int64
# InternetUsageHours      float64
# ExtraClasses             object
# Result                   object
# dtype: object

# %%
df.isnull().sum()
# Out:
# StudentID               0
# Gender                  0
# Age                     0
# StudyHoursPerDay        0
# AttendancePercentage    0
# AssignmentsCompleted    0
# SleepHours              0
# PreviousGrade           0
# InternetUsageHours      0
# ExtraClasses            0
# Result                  0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0
